# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoProfe666/Matematica-Numerica-Google-Colab/blob/main/notebooks/extras/Graficar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graficar Funciones

# %% [markdown]
# Esta sección permite graficar funciones usando diferentes bibliotecas de `Python`

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Descripción
# Sección dedicada a graficar usando la biblioteca `matplotlib`
#
# La documentación referente a esta librería se encuentra [aquí](https://colab.research.google.com/github/EduardoProfe666/Matematica-Numerica-Google-Colab/blob/main/notebooks/tutoriales-generales/Matplotlib%20Graficar.ipynb)

# %% [markdown]
# ### Importaciones

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# ### Playground

# %%
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Simpy

# %% [markdown]
# ### Descripción
# Sección dedicada a graficar usando la biblioteca `simpy`
#
# La documentación referente a esta librería se encuentra [aquí](https://colab.research.google.com/github/EduardoProfe666/Matematica-Numerica-Google-Colab/blob/main/notebooks/tutoriales-generales/Simpy%20Graficar.ipynb)

# %% [markdown]
# ### Importaciones

# %%
from sympy import symbols
from sympy.plotting import plot

# %% [markdown]
# ### Playground

# %%
x = symbols('x')

plot(x**2, (x, -5, 5))
